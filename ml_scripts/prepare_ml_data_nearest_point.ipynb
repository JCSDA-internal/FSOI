# %% [markdown]
# <h1><center><font color = 'blue'>Prepare ML data</font></center></h1>

# %%
import multiprocessing as mp
import pandas as pd
import numpy as np
import sagemaker
import boto3
import glob
import time
import os
import re

from sagemaker import get_execution_role
from scipy.spatial import cKDTree
from math import trunc

# %%
# !conda install -y xarray netcdf4
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.8
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - netcdf4
#     - xarray
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libnetcdf-4.6.1            |       h13459d8_0         1.2 MB
#     h5py-2.8.0                 |   py36h8d01980_0         1.1 MB
#     pytables-3.4.4             |   py36ha205bf6_0         1.5 MB
#     xarray-0.10.8              |           py36_0         730 KB
#     hdf4-4.2.13                |       h3ca952b_2         916 KB
#     cftime-1.0.0b1             |   py36h035aef0_0         260 KB
#     netcdf4-1.4.0              |   py36ha06eab4_1         536 KB
#     ------------------------------------------------------------
#                                            Total:         6.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     cftime:          1.0.0b1-py36h035aef0_0
#     hdf4:            4.2.13-h3ca952b_2
#     libnetcdf:       4.6.1-h13459d8_0
#     netcdf4:         1.4.0-py36ha06eab4_1
#     xarray:          0.10.8-py36_0
#
# The following packages will be UPDATED:
#
#     certifi:         2018.4.16-py36_0                      conda-forge --> 2018.4.16-py36_0
#     h5py:            2.8.0-py36h470a237_0                  conda-forge --> 2.8.0-py36h8d01980_0
#     hdf5:            1.10.1-2                              conda-forge --> 1.10.2-hba1933b_1
#     openssl:         1.0.2o-0                              conda-forge --> 1.0.2o-h20670df_0
#
# The following packages will be DOWNGRADED:
#
#     blas:            1.1-openblas                          conda-forge --> 1.0-mkl
#     ca-certificates: 2018.4.16-0                           conda-forge --> 2018.03.07-0
#     numpy:           1.14.5-py36_blas_openblashd3ea46f_200 conda-forge [blas_openblas] --> 1.14.3-py36h28100ab_2
#     opencv:          3.4.1-py36_blas_openblas_200          conda-forge [blas_openblas] --> 3.4.1-py36h6fd60c2_1
#     pytables:        3.4.4-py36_8                          conda-forge --> 3.4.4-py36ha205bf6_0
#     scikit-learn:    0.19.1-py36_blas_openblas_201         conda-forge [blas_openblas] --> 0.19.1-py36h7aa7ec6_0
#     scipy:           1.1.0-py36_blas_openblas_200          conda-forge [blas_openblas] --> 1.1.0-py36hfc37229_0
#
#
# Downloading and Extracting Packages
# libnetcdf 4.6.1: ####################################################### | 100%
# h5py 2.8.0: ############################################################ | 100%
# pytables 3.4.4: ######################################################## | 100%
# xarray 0.10.8: ######################################################### | 100%
# hdf4 4.2.13: ########################################################### | 100%
# cftime 1.0.0b1: ######################################################## | 100%
# netcdf4 1.4.0: ######################################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import multiprocessing as mp
import xarray as xr
import pandas as pd
import numpy as np
import sagemaker
import boto3
import glob
import time
import os
import re

from sagemaker import get_execution_role
from scipy.spatial import cKDTree
from math import trunc

# %%
# define a function that loads obs and bkg data into pandas dataframes
def load_data(filepath, date):
    resource = boto3.resource("s3")
    filename = "/tmp/" + filepath.split("/")[-1]
    resource.Bucket("fsoi").download_file(filepath, filename)
    
    obs = pd.read_hdf(filename).xs(["AMSUA_METOP-B", 6], level=["PLATFORM", "CHANNEL"])
    os.remove(filename)
    
    obs = obs.reset_index(level=[0, 1])
    obs = obs.drop(["OBTYPE", "OBERR", "PRESSURE"], axis=1)
    
    # fix lon between -180/180 instead of 0/360
    mask_lon = obs[obs["LONGITUDE"] > 180].index.tolist()
    obs.loc[mask_lon, "LONGITUDE"] = obs.loc[mask_lon, "LONGITUDE"] - 360
    
    date = date[:-2] + "_" + date[-2:]
    month = date[:4] + "_" + date[4:6] + "/"
    filename = "e5130_hyb_01.bkg.eta." + date + "z.nc4"
    filepath = "bkg/" + month + filename
    filename = "/tmp/" + filename
    resource.Bucket("fsoi").download_file(filepath, filename)
    
    bkg = xr.open_dataset(filename).to_dataframe()\
            .reset_index(level=[0, 1, 2])
    
    os.remove(filename)
            
    obs = obs.sort_values(["LONGITUDE", "LATITUDE"]).reset_index(drop=True)
    bkg = bkg.sort_values(["lon", "lat"]).reset_index(drop=True)
        
    return obs, bkg


# define kdtree function that return pts1 indexes of nearest point from pts2
def do_kdtree(pts1, pts2):
    mytree = cKDTree(pts1)
    dist, indexes = mytree.query(pts2)
    return indexes


# define a function that gets nearest bkg point for each observation
def get_nearest(obs, bkg):
    obs_pts = obs[["LONGITUDE", "LATITUDE"]].as_matrix()
    bkg_pts = bkg[["lon", "lat"]].as_matrix()
    
    nearest_ix = do_kdtree(bkg_pts, obs_pts)
    bkg_nearest = bkg.iloc[nearest_ix]
    
    return bkg_nearest


# define a function that gets bkg levels data for a particular point
def get_lev_data(bkg, ix, lev_cols):
    return bkg.loc[ix:ix + 71, lev_cols[1:]].copy().stack().reset_index(drop=True)


# define a function that adds level data from bkg 3D to 2D by transposing it
def add_lev_data(bkg, bkg_2D, level_cols, levels):
    lev_data = []
    bkg_2D.index.map(lambda ix: lev_data.append(get_lev_data(bkg, ix, level_cols)))
    lev_data = pd.concat(lev_data, axis=1).transpose()
    
    # set level column names (!! levels are different depending on the files)
    # levels = [round(lev, 3) for lev in bkg.lev.unique()]
    lev_data.columns = [
            col + '_' + lev
            for lev in levels
            for col in level_cols[1:]
            ]
    
    bkg_2D.reset_index(drop=True, inplace=True)
    bkg_2D = pd.concat([bkg_2D, lev_data], axis=1)
    
    return bkg_2D


# define a function that merges our training data from all files
def merge_train_data(filepaths, levels, i, n):
    level_cols = ["lev", "delp", "u", "v", "tv", "sphu", "ozone", "qitot", "qltot"]
    ml_data = pd.DataFrame()
    
    for j in range(i, len(filepaths), n):
        
        start = time.time()
        
        filepath = filepaths[j]
        date = re.findall("[0-9]+.h5", filepath)[0][:-3]
        obs, bkg = load_data(filepath, date)
        
        mask_2D = np.arange(0, len(bkg), 72)
        bkg_2D = bkg.drop(level_cols, axis=1).loc[mask_2D, :]
        
        bkg_nearest = get_nearest(obs, bkg_2D)
        bkg_nearest = add_lev_data(bkg, bkg_nearest, level_cols, levels)
        
        merge = pd.concat([obs, bkg_nearest], axis=1)
        ml_data = pd.concat([ml_data, merge], axis=0)
        
        end = time.time()
        print("Merge {} obs and bkg done in: {} min and {} sec".format(
            date, trunc((end - start)/60), round((end - start)%60)
        ))
        
    return ml_data

# %%
pstart = time.time()

client = boto3.client("s3")
resource = boto3.resource("s3")

months = ["2014_12", "2015_01", "2015_02"]
filepaths = []

for month in months:
    monthpaths = client.list_objects(Bucket="fsoi", Prefix="obs/GMAO_" + month + "/GMAO.dry.")
    filepaths += [dic["Key"] for dic in monthpaths["Contents"]]

# import levels
filename = "levels.txt"

resource.Bucket("fsoi").download_file(filename, filename)

f = open(filename, "r")
levels = f.read().split("\n")
f.close()

os.remove(filename)

# define how many process we want to run
n = 12
pool = mp.Pool(processes=n)

# run our processes
results = [
        pool.apply_async(merge_train_data, args=(filepaths, levels, i, n))
        for i in range(n)
        ]

results = [p.get() for p in results]

# merge our training data
ml_data = pd.concat(results, axis=0)

# save and compress training data in hdf5 format
start = time.time()

filename = "amsua_metop_b_ch6.h5"
key = "ml_data/" + filename
filename = "/tmp/" + filename

ml_data = ml_data.sort_values(["DATETIME", "LATITUDE", "LONGITUDE"])\
                 .reset_index(drop=True)
                             
ml_data.to_hdf(filename, key="df", complevel=9)

resource.Bucket("fsoi").upload_file(filename, key)

os.remove(filename)

end = time.time()
print("Saved and compressed in: {} min and {} sec".format(trunc((end - start)/60),
                                                          round((end - start)%60)))
    
# display total program time
pend = time.time()
print("Total program took: {} hours and {} min".format(trunc((pend - pstart)/3600),
                                                       round((pend - pstart)%3600/60)))
# Out:
# Merge 2014120118 obs and bkg done in: 0 min and 48 sec
# Merge 2014120200 obs and bkg done in: 0 min and 48 sec
# Merge 2014120312 obs and bkg done in: 0 min and 48 sec
# Merge 2014120206 obs and bkg done in: 0 min and 48 sec
# Merge 2014120106 obs and bkg done in: 0 min and 48 sec
# Merge 2014120100 obs and bkg done in: 0 min and 48 sec
# Merge 2014120218 obs and bkg done in: 0 min and 48 sec
# Merge 2014120300 obs and bkg done in: 0 min and 49 sec
# Merge 2014120112 obs and bkg done in: 0 min and 57 sec
# Merge 2014120500 obs and bkg done in: 0 min and 45 sec
# Merge 2014120506 obs and bkg done in: 0 min and 45 sec
# Merge 2014120612 obs and bkg done in: 0 min and 46 sec
# Merge 2014120400 obs and bkg done in: 0 min and 46 sec
# Merge 2014120406 obs and bkg done in: 0 min and 46 sec
# Merge 2014120518 obs and bkg done in: 0 min and 46 sec
# Merge 2014120600 obs and bkg done in: 0 min and 46 sec
# Merge 2014120418 obs and bkg done in: 0 min and 47 sec
# Merge 2014120212 obs and bkg done in: 1 min and 53 sec
# Merge 2014120412 obs and bkg done in: 0 min and 58 sec
# Merge 2014120318 obs and bkg done in: 2 min and 8 sec
# Merge 2014120806 obs and bkg done in: 0 min and 45 sec
# Merge 2014120706 obs and bkg done in: 0 min and 45 sec
# Merge 2014120800 obs and bkg done in: 0 min and 46 sec
# Merge 2014120912 obs and bkg done in: 0 min and 46 sec
# Merge 2014120900 obs and bkg done in: 0 min and 45 sec
# Merge 2014120700 obs and bkg done in: 0 min and 47 sec
# Merge 2014120306 obs and bkg done in: 2 min and 21 sec
# Merge 2014120818 obs and bkg done in: 0 min and 47 sec
# Merge 2014120718 obs and bkg done in: 0 min and 48 sec
# Merge 2014120512 obs and bkg done in: 0 min and 45 sec
# Merge 2014120712 obs and bkg done in: 0 min and 46 sec
# Merge 2014121106 obs and bkg done in: 0 min and 38 sec
# Merge 2014121100 obs and bkg done in: 0 min and 37 sec
# Merge 2014121018 obs and bkg done in: 0 min and 40 sec
# Merge 2014121006 obs and bkg done in: 0 min and 44 sec
# Merge 2014121212 obs and bkg done in: 0 min and 44 sec
# Merge 2014121200 obs and bkg done in: 0 min and 44 sec
# Merge 2014121118 obs and bkg done in: 0 min and 43 sec
# Merge 2014120618 obs and bkg done in: 0 min and 57 sec
# Merge 2014121000 obs and bkg done in: 0 min and 47 sec
# Merge 2014120606 obs and bkg done in: 0 min and 48 sec
# Merge 2014121012 obs and bkg done in: 0 min and 40 sec
# Merge 2014120812 obs and bkg done in: 0 min and 46 sec
# Merge 2014121406 obs and bkg done in: 0 min and 46 sec
# Merge 2014121400 obs and bkg done in: 0 min and 46 sec
# Merge 2014121512 obs and bkg done in: 0 min and 45 sec
# Merge 2014121318 obs and bkg done in: 0 min and 47 sec
# Merge 2014121300 obs and bkg done in: 0 min and 46 sec
# Merge 2014120906 obs and bkg done in: 0 min and 45 sec
# Merge 2014121112 obs and bkg done in: 0 min and 39 sec
# Merge 2014121312 obs and bkg done in: 0 min and 46 sec
# Merge 2014121700 obs and bkg done in: 0 min and 47 sec
# Merge 2014121706 obs and bkg done in: 0 min and 47 sec
# Merge 2014121500 obs and bkg done in: 1 min and 30 sec
# Merge 2014120918 obs and bkg done in: 1 min and 29 sec
# Merge 2014121618 obs and bkg done in: 0 min and 46 sec
# Merge 2014121812 obs and bkg done in: 0 min and 47 sec
# Merge 2014121306 obs and bkg done in: 1 min and 34 sec
# Merge 2014121418 obs and bkg done in: 1 min and 34 sec
# Merge 2014121600 obs and bkg done in: 0 min and 46 sec
# Merge 2014121206 obs and bkg done in: 0 min and 46 sec
# Merge 2014121412 obs and bkg done in: 0 min and 45 sec
# Merge 2014121612 obs and bkg done in: 0 min and 45 sec
# Merge 2014122006 obs and bkg done in: 0 min and 46 sec
# Merge 2014122000 obs and bkg done in: 0 min and 48 sec
# Merge 2014121800 obs and bkg done in: 0 min and 48 sec
# Merge 2014122112 obs and bkg done in: 0 min and 47 sec
# Merge 2014121900 obs and bkg done in: 0 min and 48 sec
# Merge 2014121712 obs and bkg done in: 0 min and 48 sec
# Merge 2014121912 obs and bkg done in: 0 min and 46 sec
# Merge 2014122306 obs and bkg done in: 0 min and 46 sec
# Merge 2014122300 obs and bkg done in: 0 min and 46 sec
# Merge 2014122100 obs and bkg done in: 0 min and 47 sec
# Merge 2014122412 obs and bkg done in: 0 min and 47 sec
# Merge 2014122200 obs and bkg done in: 0 min and 47 sec
# Merge 2014121218 obs and bkg done in: 1 min and 44 sec
# Merge 2014121506 obs and bkg done in: 1 min and 43 sec
# Merge 2014121918 obs and bkg done in: 1 min and 47 sec
# Merge 2014121606 obs and bkg done in: 1 min and 45 sec
# Merge 2014121718 obs and bkg done in: 1 min and 45 sec
# Merge 2014122012 obs and bkg done in: 0 min and 47 sec
# Merge 2014122212 obs and bkg done in: 0 min and 47 sec
# Merge 2014122606 obs and bkg done in: 0 min and 47 sec
# Merge 2014122600 obs and bkg done in: 0 min and 48 sec
# Merge 2014122400 obs and bkg done in: 0 min and 48 sec
# Merge 2014122712 obs and bkg done in: 0 min and 48 sec
# Merge 2014122500 obs and bkg done in: 0 min and 49 sec
# Merge 2014121518 obs and bkg done in: 0 min and 47 sec
# Merge 2014121906 obs and bkg done in: 0 min and 46 sec
# Merge 2014121806 obs and bkg done in: 0 min and 47 sec
# Merge 2014122312 obs and bkg done in: 0 min and 47 sec
# Merge 2014122018 obs and bkg done in: 0 min and 48 sec
# Merge 2014122218 obs and bkg done in: 0 min and 49 sec
# Merge 2014122512 obs and bkg done in: 0 min and 46 sec
# Merge 2014122906 obs and bkg done in: 0 min and 48 sec
# Merge 2014122900 obs and bkg done in: 0 min and 48 sec
# Merge 2014123012 obs and bkg done in: 0 min and 46 sec
# Merge 2014122700 obs and bkg done in: 0 min and 48 sec
# Merge 2014122800 obs and bkg done in: 0 min and 47 sec
# Merge 2014121818 obs and bkg done in: 0 min and 49 sec
# Merge 2014122206 obs and bkg done in: 0 min and 46 sec
# Merge 2014122612 obs and bkg done in: 0 min and 46 sec
# Merge 2014122106 obs and bkg done in: 0 min and 47 sec
# Merge 2014122812 obs and bkg done in: 0 min and 45 sec
# Merge 2014122318 obs and bkg done in: 0 min and 47 sec
# Merge 2014122518 obs and bkg done in: 0 min and 47 sec
# Merge 2015010106 obs and bkg done in: 0 min and 46 sec
# Merge 2015010100 obs and bkg done in: 0 min and 48 sec
# Merge 2015010212 obs and bkg done in: 0 min and 45 sec
# Merge 2014123000 obs and bkg done in: 0 min and 47 sec
# Merge 2014123100 obs and bkg done in: 0 min and 46 sec
# Merge 2014122118 obs and bkg done in: 0 min and 47 sec
# Merge 2014122506 obs and bkg done in: 0 min and 46 sec
# Merge 2014123112 obs and bkg done in: 0 min and 45 sec
# Merge 2014122912 obs and bkg done in: 0 min and 47 sec
# Merge 2014122406 obs and bkg done in: 0 min and 47 sec
# Merge 2014122618 obs and bkg done in: 0 min and 46 sec
# Merge 2014122818 obs and bkg done in: 0 min and 48 sec
# Merge 2015010406 obs and bkg done in: 0 min and 47 sec
# Merge 2015010512 obs and bkg done in: 0 min and 46 sec
# Merge 2015010400 obs and bkg done in: 0 min and 48 sec
# Merge 2015010200 obs and bkg done in: 0 min and 48 sec
# Merge 2015010300 obs and bkg done in: 0 min and 48 sec
# Merge 2014122418 obs and bkg done in: 0 min and 47 sec
# Merge 2014123118 obs and bkg done in: 0 min and 49 sec
# Merge 2014122806 obs and bkg done in: 1 min and 5 sec
# Merge 2014122918 obs and bkg done in: 1 min and 3 sec
# Merge 2015010112 obs and bkg done in: 1 min and 4 sec
# Merge 2014122706 obs and bkg done in: 1 min and 4 sec
# Merge 2015010312 obs and bkg done in: 1 min and 5 sec
# Merge 2015010706 obs and bkg done in: 0 min and 47 sec
# Merge 2015010700 obs and bkg done in: 0 min and 47 sec
# Merge 2015010812 obs and bkg done in: 0 min and 48 sec
# Merge 2015010500 obs and bkg done in: 0 min and 48 sec
# Merge 2015010600 obs and bkg done in: 0 min and 49 sec
# Merge 2014122718 obs and bkg done in: 0 min and 46 sec
# Merge 2015010318 obs and bkg done in: 0 min and 50 sec
# Merge 2014123106 obs and bkg done in: 0 min and 46 sec
# Merge 2015010118 obs and bkg done in: 0 min and 47 sec
# Merge 2015010412 obs and bkg done in: 0 min and 47 sec
# Merge 2015010612 obs and bkg done in: 0 min and 46 sec
# Merge 2014123006 obs and bkg done in: 0 min and 48 sec
# Merge 2015011006 obs and bkg done in: 0 min and 43 sec
# Merge 2015011000 obs and bkg done in: 0 min and 44 sec
# Merge 2015011112 obs and bkg done in: 0 min and 45 sec
# Merge 2015010800 obs and bkg done in: 0 min and 47 sec
# Merge 2015010900 obs and bkg done in: 0 min and 46 sec
# Merge 2014123018 obs and bkg done in: 0 min and 46 sec
# Merge 2015010618 obs and bkg done in: 0 min and 47 sec
# Merge 2015010912 obs and bkg done in: 0 min and 44 sec
# Merge 2015010306 obs and bkg done in: 0 min and 48 sec
# Merge 2015010206 obs and bkg done in: 0 min and 46 sec
# Merge 2015010712 obs and bkg done in: 0 min and 47 sec
# Merge 2015010418 obs and bkg done in: 0 min and 48 sec
# Merge 2015011306 obs and bkg done in: 0 min and 44 sec
# Merge 2015011412 obs and bkg done in: 0 min and 46 sec
# Merge 2015011300 obs and bkg done in: 0 min and 48 sec
# Merge 2015011100 obs and bkg done in: 0 min and 47 sec
# Merge 2015011200 obs and bkg done in: 0 min and 47 sec
# Merge 2015010218 obs and bkg done in: 0 min and 48 sec
# Merge 2015010918 obs and bkg done in: 0 min and 44 sec
# Merge 2015011212 obs and bkg done in: 0 min and 47 sec
# Merge 2015011012 obs and bkg done in: 0 min and 45 sec
# Merge 2015010606 obs and bkg done in: 0 min and 47 sec
# Merge 2015010506 obs and bkg done in: 0 min and 47 sec
# Merge 2015010718 obs and bkg done in: 0 min and 47 sec
# Merge 2015011606 obs and bkg done in: 0 min and 48 sec
# Merge 2015011712 obs and bkg done in: 0 min and 48 sec
# Merge 2015011600 obs and bkg done in: 0 min and 50 sec
# Merge 2015011400 obs and bkg done in: 0 min and 47 sec
# Merge 2015011500 obs and bkg done in: 0 min and 47 sec
# Merge 2015010518 obs and bkg done in: 0 min and 49 sec
# Merge 2015011218 obs and bkg done in: 0 min and 47 sec
# Merge 2015010906 obs and bkg done in: 0 min and 43 sec
# Merge 2015011512 obs and bkg done in: 0 min and 47 sec
# Merge 2015011312 obs and bkg done in: 0 min and 48 sec
# Merge 2015010806 obs and bkg done in: 0 min and 47 sec
# Merge 2015011018 obs and bkg done in: 0 min and 48 sec
# Merge 2015011906 obs and bkg done in: 0 min and 48 sec
# Merge 2015012012 obs and bkg done in: 0 min and 48 sec
# Merge 2015011900 obs and bkg done in: 0 min and 49 sec
# Merge 2015011700 obs and bkg done in: 0 min and 47 sec
# Merge 2015011800 obs and bkg done in: 0 min and 49 sec
# Merge 2015010818 obs and bkg done in: 0 min and 46 sec
# Merge 2015011518 obs and bkg done in: 0 min and 47 sec
# Merge 2015011206 obs and bkg done in: 0 min and 47 sec
# Merge 2015011812 obs and bkg done in: 0 min and 48 sec
# Merge 2015011612 obs and bkg done in: 0 min and 49 sec
# Merge 2015011106 obs and bkg done in: 0 min and 49 sec
# Merge 2015011318 obs and bkg done in: 0 min and 48 sec
# Merge 2015012206 obs and bkg done in: 0 min and 46 sec
# Merge 2015012312 obs and bkg done in: 0 min and 51 sec
# Merge 2015012200 obs and bkg done in: 0 min and 48 sec
# Merge 2015012000 obs and bkg done in: 0 min and 50 sec
# Merge 2015011118 obs and bkg done in: 0 min and 46 sec
# Merge 2015012100 obs and bkg done in: 0 min and 50 sec
# Merge 2015011818 obs and bkg done in: 0 min and 49 sec
# Merge 2015011506 obs and bkg done in: 0 min and 49 sec
# Merge 2015012112 obs and bkg done in: 0 min and 47 sec
# Merge 2015011912 obs and bkg done in: 0 min and 47 sec
# Merge 2015011406 obs and bkg done in: 0 min and 46 sec
# Merge 2015011618 obs and bkg done in: 0 min and 47 sec
# Merge 2015012506 obs and bkg done in: 0 min and 47 sec
# Merge 2015012612 obs and bkg done in: 0 min and 48 sec
# Merge 2015012500 obs and bkg done in: 0 min and 48 sec
# Merge 2015012300 obs and bkg done in: 0 min and 48 sec
# Merge 2015011418 obs and bkg done in: 0 min and 47 sec
# Merge 2015012400 obs and bkg done in: 0 min and 49 sec
# Merge 2015012118 obs and bkg done in: 0 min and 49 sec
# Merge 2015011806 obs and bkg done in: 0 min and 47 sec
# Merge 2015012412 obs and bkg done in: 0 min and 47 sec
# Merge 2015011706 obs and bkg done in: 0 min and 47 sec
# Merge 2015012212 obs and bkg done in: 0 min and 48 sec
# Merge 2015012806 obs and bkg done in: 0 min and 47 sec
# Merge 2015011918 obs and bkg done in: 0 min and 50 sec
# Merge 2015012800 obs and bkg done in: 0 min and 47 sec
# Merge 2015012912 obs and bkg done in: 0 min and 48 sec
# Merge 2015012600 obs and bkg done in: 0 min and 48 sec
# Merge 2015011718 obs and bkg done in: 0 min and 47 sec
# Merge 2015012700 obs and bkg done in: 0 min and 48 sec
# Merge 2015012418 obs and bkg done in: 0 min and 50 sec
# Merge 2015012106 obs and bkg done in: 0 min and 47 sec
# Merge 2015012712 obs and bkg done in: 0 min and 48 sec
# Merge 2015012006 obs and bkg done in: 0 min and 47 sec
# Merge 2015012512 obs and bkg done in: 0 min and 48 sec
# Merge 2015013106 obs and bkg done in: 0 min and 51 sec
# Merge 2015012218 obs and bkg done in: 0 min and 49 sec
# Merge 2015020112 obs and bkg done in: 0 min and 49 sec
# Merge 2015013100 obs and bkg done in: 0 min and 50 sec
# Merge 2015012900 obs and bkg done in: 0 min and 47 sec
# Merge 2015012018 obs and bkg done in: 0 min and 51 sec
# Merge 2015013000 obs and bkg done in: 0 min and 48 sec
# Merge 2015012718 obs and bkg done in: 0 min and 47 sec
# Merge 2015012406 obs and bkg done in: 0 min and 48 sec
# Merge 2015012306 obs and bkg done in: 0 min and 47 sec
# Merge 2015013012 obs and bkg done in: 0 min and 49 sec
# Merge 2015012812 obs and bkg done in: 0 min and 48 sec
# Merge 2015012518 obs and bkg done in: 0 min and 48 sec
# Merge 2015020306 obs and bkg done in: 0 min and 50 sec
# Merge 2015020412 obs and bkg done in: 0 min and 49 sec
# Merge 2015020300 obs and bkg done in: 0 min and 49 sec
# Merge 2015020100 obs and bkg done in: 0 min and 48 sec
# Merge 2015012318 obs and bkg done in: 0 min and 47 sec
# Merge 2015020200 obs and bkg done in: 0 min and 51 sec
# Merge 2015013018 obs and bkg done in: 0 min and 47 sec
# Merge 2015012706 obs and bkg done in: 0 min and 48 sec
# Merge 2015012606 obs and bkg done in: 0 min and 47 sec
# Merge 2015020212 obs and bkg done in: 0 min and 48 sec
# Merge 2015013112 obs and bkg done in: 0 min and 49 sec
# Merge 2015012818 obs and bkg done in: 0 min and 47 sec
# Merge 2015020606 obs and bkg done in: 0 min and 48 sec
# Merge 2015020712 obs and bkg done in: 0 min and 47 sec
# Merge 2015020600 obs and bkg done in: 0 min and 49 sec
# Merge 2015020400 obs and bkg done in: 0 min and 50 sec
# Merge 2015012618 obs and bkg done in: 0 min and 48 sec
# Merge 2015020500 obs and bkg done in: 0 min and 49 sec
# Merge 2015020218 obs and bkg done in: 0 min and 50 sec
# Merge 2015013006 obs and bkg done in: 0 min and 48 sec
# Merge 2015012906 obs and bkg done in: 0 min and 47 sec
# Merge 2015020512 obs and bkg done in: 0 min and 49 sec
# Merge 2015020312 obs and bkg done in: 0 min and 49 sec
# Merge 2015013118 obs and bkg done in: 0 min and 49 sec
# Merge 2015020906 obs and bkg done in: 0 min and 49 sec
# Merge 2015021012 obs and bkg done in: 0 min and 47 sec
# Merge 2015020900 obs and bkg done in: 0 min and 49 sec
# Merge 2015020700 obs and bkg done in: 0 min and 50 sec
# Merge 2015012918 obs and bkg done in: 0 min and 49 sec
# Merge 2015020800 obs and bkg done in: 0 min and 48 sec
# Merge 2015020518 obs and bkg done in: 0 min and 48 sec
# Merge 2015020206 obs and bkg done in: 0 min and 48 sec
# Merge 2015020106 obs and bkg done in: 0 min and 47 sec
# Merge 2015020812 obs and bkg done in: 0 min and 49 sec
# Merge 2015020612 obs and bkg done in: 0 min and 50 sec
# Merge 2015020318 obs and bkg done in: 0 min and 48 sec
# Merge 2015021206 obs and bkg done in: 0 min and 49 sec
# Merge 2015021312 obs and bkg done in: 0 min and 48 sec
# Merge 2015021200 obs and bkg done in: 0 min and 50 sec
# Merge 2015020118 obs and bkg done in: 0 min and 48 sec
# Merge 2015021000 obs and bkg done in: 0 min and 49 sec
# Merge 2015021100 obs and bkg done in: 0 min and 50 sec
# Merge 2015020818 obs and bkg done in: 0 min and 48 sec
# Merge 2015020506 obs and bkg done in: 0 min and 49 sec
# Merge 2015020406 obs and bkg done in: 0 min and 47 sec
# Merge 2015021112 obs and bkg done in: 0 min and 48 sec
# Merge 2015020912 obs and bkg done in: 0 min and 47 sec
# Merge 2015020618 obs and bkg done in: 0 min and 48 sec
# Merge 2015021506 obs and bkg done in: 0 min and 51 sec
# Merge 2015021612 obs and bkg done in: 0 min and 48 sec
# Merge 2015020418 obs and bkg done in: 0 min and 48 sec
# Merge 2015021500 obs and bkg done in: 0 min and 50 sec
# Merge 2015021300 obs and bkg done in: 0 min and 51 sec
# Merge 2015020806 obs and bkg done in: 0 min and 47 sec
# Merge 2015021400 obs and bkg done in: 0 min and 52 sec
# Merge 2015021118 obs and bkg done in: 0 min and 49 sec
# Merge 2015020706 obs and bkg done in: 0 min and 48 sec
# Merge 2015021412 obs and bkg done in: 0 min and 49 sec
# Merge 2015021212 obs and bkg done in: 0 min and 49 sec
# Merge 2015020918 obs and bkg done in: 0 min and 48 sec
# Merge 2015021806 obs and bkg done in: 0 min and 50 sec
# Merge 2015021912 obs and bkg done in: 0 min and 48 sec
# Merge 2015020718 obs and bkg done in: 0 min and 47 sec
# Merge 2015021800 obs and bkg done in: 0 min and 50 sec
# Merge 2015021600 obs and bkg done in: 0 min and 49 sec
# Merge 2015021006 obs and bkg done in: 0 min and 53 sec
# Merge 2015021418 obs and bkg done in: 0 min and 54 sec
# Merge 2015021106 obs and bkg done in: 0 min and 56 sec
# Merge 2015021712 obs and bkg done in: 0 min and 49 sec
# Merge 2015021700 obs and bkg done in: 0 min and 57 sec
# Merge 2015021512 obs and bkg done in: 0 min and 49 sec
# Merge 2015021218 obs and bkg done in: 0 min and 49 sec
# Merge 2015022106 obs and bkg done in: 0 min and 47 sec
# Merge 2015022212 obs and bkg done in: 0 min and 47 sec
# Merge 2015021018 obs and bkg done in: 0 min and 49 sec
# Merge 2015022100 obs and bkg done in: 0 min and 49 sec
# Merge 2015021900 obs and bkg done in: 0 min and 50 sec
# Merge 2015021718 obs and bkg done in: 0 min and 47 sec
# Merge 2015021406 obs and bkg done in: 0 min and 49 sec
# Merge 2015022012 obs and bkg done in: 0 min and 49 sec
# Merge 2015021306 obs and bkg done in: 0 min and 51 sec
# Merge 2015022000 obs and bkg done in: 0 min and 49 sec
# Merge 2015021812 obs and bkg done in: 0 min and 49 sec
# Merge 2015021518 obs and bkg done in: 0 min and 49 sec
# Merge 2015022406 obs and bkg done in: 0 min and 48 sec
# Merge 2015022512 obs and bkg done in: 0 min and 49 sec
# Merge 2015021318 obs and bkg done in: 0 min and 49 sec
# Merge 2015022400 obs and bkg done in: 0 min and 52 sec
# Merge 2015022200 obs and bkg done in: 0 min and 49 sec
# Merge 2015022018 obs and bkg done in: 0 min and 51 sec
# Merge 2015021606 obs and bkg done in: 0 min and 47 sec
# Merge 2015021706 obs and bkg done in: 0 min and 49 sec
# Merge 2015022312 obs and bkg done in: 0 min and 49 sec
# Merge 2015022300 obs and bkg done in: 0 min and 50 sec
# Merge 2015022112 obs and bkg done in: 0 min and 49 sec
# Merge 2015021818 obs and bkg done in: 0 min and 48 sec
# Merge 2015022706 obs and bkg done in: 0 min and 47 sec
# Merge 2015022812 obs and bkg done in: 0 min and 48 sec
# Merge 2015021618 obs and bkg done in: 0 min and 48 sec
# Merge 2015022500 obs and bkg done in: 0 min and 49 sec
# Merge 2015022700 obs and bkg done in: 0 min and 51 sec
# Merge 2015021906 obs and bkg done in: 0 min and 48 sec
# Merge 2015022006 obs and bkg done in: 0 min and 48 sec
# Merge 2015022612 obs and bkg done in: 0 min and 47 sec
# Merge 2015022318 obs and bkg done in: 0 min and 50 sec
# Merge 2015022412 obs and bkg done in: 0 min and 48 sec
# Merge 2015022600 obs and bkg done in: 0 min and 49 sec
# Merge 2015022118 obs and bkg done in: 0 min and 48 sec
# Merge 2015021918 obs and bkg done in: 0 min and 48 sec
# Merge 2015022800 obs and bkg done in: 0 min and 49 sec
# Merge 2015022206 obs and bkg done in: 0 min and 47 sec
# Merge 2015022306 obs and bkg done in: 0 min and 48 sec
# Merge 2015022618 obs and bkg done in: 0 min and 48 sec
# Merge 2015022712 obs and bkg done in: 0 min and 48 sec
# Merge 2015022418 obs and bkg done in: 0 min and 47 sec
# Merge 2015022218 obs and bkg done in: 0 min and 48 sec
# Merge 2015022506 obs and bkg done in: 0 min and 47 sec
# Merge 2015022606 obs and bkg done in: 0 min and 48 sec
# Merge 2015022718 obs and bkg done in: 0 min and 50 sec
# Merge 2015022518 obs and bkg done in: 0 min and 48 sec
# Merge 2015022806 obs and bkg done in: 0 min and 47 sec
# Merge 2015022818 obs and bkg done in: 0 min and 47 sec
# Saved and compressed in: 23 min and 4 sec
# Total program took: 0 hours and 51 min
